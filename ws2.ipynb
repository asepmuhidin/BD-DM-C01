# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/BD-DM-C01/blob/main/ws2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/asepmuhidin/MK-Data-Mining-UPB/refs/heads/main/dataset/cereal.csv')
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
data=pd.read_csv('https://raw.githubusercontent.com/asepmuhidin/MK-Data-Mining-UPB/refs/heads/main/dataset/cereal.csv')

# %%
data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
data.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# ...

# %%
data.tail(5)
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 72   21.0     3.0    60.0   FDA_25      3     1.0  0.75  39.106174
# 73   13.0    12.0    25.0   FDA_25      2     1.0  1.00  27.753301
# 74   17.0     3.0   115.0   FDA_25      1     1.0  0.67  49.787445
# 75   17.0     3.0   110.0   FDA_25      1     1.0  1.00  51.592193
# 76   16.0     8.0    60.0   FDA_25      1     1.0  0.75  36.187559

# %%
data.sample(10)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 32          Grape Nuts Flakes   P    C       100        3    1     140    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# 30               Golden Crisp   P    C       100        2    0      45    0.0
# 21                    Crispix   K    C       110        2    0     220    1.0
# 58                Raisin Bran   K    C       120        3    1     210    5.0
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# ...

# %%
data['name']
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %%
data['name'].sample(10)
# Out:
# 43                    Maypo
# 33               Grape-Nuts
# 32        Grape Nuts Flakes
# 67                Special K
# 31           Golden Grahams
# 63           Shredded Wheat
# 12    Cinnamon Toast Crunch
# 74               Wheat Chex
# 40                      Kix
# 58              Raisin Bran
# Name: name, dtype: object

# %%
data['mfr'].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
data[data['mfr']=='N']
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0     5.0     6.0   280.0   FDA_25      3    1.00  0.33  68.402973
# 20   21.0     0.0     NaN    FDA_0      2    1.00  1.00  64.533816
# 63   16.0     0.0    95.0    FDA_0      1    0.83  1.00  68.235885
# 64   19.0     0.0   140.0    FDA_0      1    1.00  0.67  74.472949
# 65   20.0     0.0   120.0    FDA_0      1    1.00  0.67  72.801787
# ...

# %%
data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass      shelf     weight       cups     rating
# count  76.000000   75.000000  77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   2.207792   1.029610   0.821039  42.665705
# std     4.378656   70.410636   0.832524   0.150477   0.232716  14.047289
# ...

# %%
data[data['calories']==160]
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 46  Mueslix Crispy Blend   K    C       160        3    2     150    3.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 46   17.0    13.0   160.0   FDA_25      3     1.5  0.67  30.313351

# %%
data[(data['calories']<data['calories'].max()) & (data['fat']>data['fat'].min())]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# ...

# %%
#Tampilkan produk dengan rating terendah
data[data['rating']==data['rating'].min()]
# Out:
#             name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 10  Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
#
#     sugars  potass vitamins  shelf  weight  cups     rating
# 10    12.0    35.0   FDA_25      2     1.0  0.75  18.042851

# %%
#Tampilkan produk dengan rating tertinggi
data[data['rating']==data['rating'].max()]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 3    8.0     0.0   330.0   FDA_25      3     1.0   0.5  93.704912

# %%
data['rating'].mean()
# Out:
# 42.66570498701299

# %%
data[['name','mfr','calories', 'rating']]
# Out:
#                          name mfr  calories     rating
# 0                   100% Bran   N        70  68.402973
# 1           100% Natural Bran   Q       120  33.983679
# 2                    All-Bran   K        70  59.425505
# 3   All-Bran with Extra Fiber   K        50  93.704912
# 4              Almond Delight   R       110  34.384843
# ..                        ...  ..       ...        ...
# 72                    Triples   G       110  39.106174
# 73                       Trix   G       110  27.753301
# 74                 Wheat Chex   R       100  49.787445
# 75                   Wheaties   G       100  51.592193
# 76        Wheaties Honey Gold   G       110  36.187559
#
# [77 rows x 4 columns]

# %%
columns=['name','fat','carbo','cups']
data[columns]
# Out:
#                          name  fat  carbo  cups
# 0                   100% Bran    1    5.0  0.33
# 1           100% Natural Bran    5    8.0  1.00
# 2                    All-Bran    1    7.0  0.33
# 3   All-Bran with Extra Fiber    0    8.0  0.50
# 4              Almond Delight    2   14.0  0.75
# ..                        ...  ...    ...   ...
# 72                    Triples    1   21.0  0.75
# 73                       Trix    1   13.0  1.00
# 74                 Wheat Chex    1   17.0  0.67
# 75                   Wheaties    1   17.0  1.00
# 76        Wheaties Honey Gold    1   16.0  0.75
#
# [77 rows x 4 columns]
